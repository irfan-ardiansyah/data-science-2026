# %% [markdown]
# <a href="https://colab.research.google.com/github/irfan-ardiansyah/data-science-2026/blob/main/Pertemuan_2_Muhammad_Irfan_Ardiansyah_250401020175_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science - Pertemuan 2
#
# Nama  : **Muhammad Irfan Ardiansyah** <br>
# NIM   : **250401020175** <br >
# Kelas : **IF401**

# %%
import pandas as pd
import numpy as np

URL = "http://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"

df = pd.read_csv(URL)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df.shape, df.columns.tolist())
print("-----------------------------")
print(df.isnull().sum())
# Out:
# (891, 12) ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
# -----------------------------
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Filtering — Penumpang Wanita Kelas 1
wk1 = df[(df['Sex']=='female') & (df['Pclass']==1)]
wk1

# Rounding result
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
mean_survived = wk1['Survived'].mean()
mean_age = wk1['Age'].mean()

print("============== Raw Result ===============")
print("mean of survived:", mean_survived)
print("mean of age:", mean_age)

print("\n============== Rounded Result ===============")
print("mean of survived:", round(mean_survived, 3))
print("mean of age:", round(mean_age, 3))
# Out:
# ============== Raw Result ===============
# mean of survived: 0.9680851063829787
# mean of age: 34.61176470588235
#
# ============== Rounded Result ===============
# mean of survived: 0.968
# mean of age: 34.612

# %%
# Groupby — Tingkat Keselamatan per Kelas
hasil = df.groupby('Pclass').agg(total=('PassengerId','count'), selamat=('Survived','mean')).round(3)
print(hasil)
# Out:
#         total  selamat
# Pclass
# 1         216    0.630
# 2         184    0.473
# 3         491    0.242

# %%
# Jawaban
print("1. Jumlah baris & kolom")
print("baris:", df.shape[0])
print("kolom", df.shape[1])
print("\n")

print("2. Kolom yang bernilai kosong")
print("Kolom kosong:", df.columns[df.isnull().sum() != 0].tolist())
print("\n")

print("3. Persentase penumpang selamat")
survived = len(df[(df["Survived"]==1)]) / df.shape[0] * 100
print(round(survived, 2), "%")
print("\n")


print("4. Rata-rata usia penumpang wanita kelas 1 yang selamat")
print(round(mean_age, 2), "%")
print("\n")


print("5. Kelas penumpang mana yang tingkat keselamatan tertinggi")
print("Kelas ", hasil["selamat"].idxmax() )
print("\n")


print("6. Tampilkan hasil groupby('Pclass')['Survived'].mean()")
print(df.groupby("Pclass")['Survived'].mean().round(2) )
print("\n")
# Out:
# 1. Jumlah baris & kolom
# baris: 891
# kolom 12
#
#
# 2. Kolom yang bernilai kosong
# Kolom kosong: ['Age', 'Cabin', 'Embarked']
#
#
# 3. Persentase penumpang selamat
# 38.38 %
#
#
# 4. Rata-rata usia penumpang wanita kelas 1 yang selamat
# 34.61 %
#
#
# 5. Kelas penumpang mana yang tingkat keselamatan tertinggi
# Kelas  1
#
#
# 6. Tampilkan hasil groupby('Pclass')['Survived'].mean()
# Pclass
# 1    0.63
# 2    0.47
# 3    0.24
# Name: Survived, dtype: float64

# %% [markdown]
# ## Kesimpulan
# Pada pertemuan ini membahas tentang load data csv untuk diolah, aplikasi filter sederhana. Saya mempelajari bagaimana untu missing value dan penyajian data sederhana
#
# ## Pertanyaan
# Bagaimana jika data berasal dari database seperti MySQL, PostgreSQL, apakah prosesnya akan sama?
