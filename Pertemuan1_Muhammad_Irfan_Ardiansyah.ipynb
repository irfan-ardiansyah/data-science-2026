# %% [markdown]
# <a href="https://colab.research.google.com/github/irfan-ardiansyah/data-science-2026/blob/main/Pertemuan1_Muhammad_Irfan_Ardiansyah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science - Pertemuan 1
#
# Nama  : **Muhammad Irfan Ardiansyah** <br>
# NIM   : **250401020175** <br >
# Kelas : **IF401**

# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
nama = "Mahasiswa Informatika"
angkatan = 2024
print(f"Halo, {nama} angkatan {angkatan}!")
# Out:
# Halo, Mahasiswa Informatika angkatan 2024!

# %%
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
#  1. Python
#  2. Colab
#  3. Jupyter
#  4. GitHub

# %%
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"

print(perkenalan("Budi","Informatika",2024))
# Out:
# Budi | Informatika | 2024

# %% [markdown]
# ## Kesimpulan
# Pada pertumuan ini membahas tentang dasar pemrograman python. beberapa hal yang dipelajari adalah variable, perulangan, function yang nantinya digunakan dalaman Data Science dan Artifical Intelligence
#
# ## Pertanyaan
# Apakah hanya python yang digunakan untuk Data Science? apakah bahasa pemrograman lain tidak bisa?
